# %%
import pandas as pd

# Load the compiled CSV dataset
try:
    df = pd.read_csv('financial_data.csv')
    print("Dataset successfully loaded!")
    display(df.head(9))
except FileNotFoundError:
    print("Error: Make sure 'financial_data.csv' is saved in the same folder as this notebook.")
# Out:
# Dataset successfully loaded!
#   Company,Year,Total Revenue,Net Income,Total Assets,Total Liabilities,Operating Cash Flow
# 0    Microsoft,2023,211915,72361,411976,205753,87582
# 1   Microsoft,2024,245122,88136,512503,230134,118548
# 2   Microsoft,2025,281700,98000,580000,250000,135000
# 3           Tesla,2023,96773,15000,93409,43009,13256
# 4           Tesla,2024,97689,7090,110450,45120,14000
# 5        Tesla,2025,115000,95000,125000,48000,165000
# 6       Apple,2023,383285,96995,352581,272408,110543
# 7       Apple,2024,391035,93736,364980,277327,123216
# 8      Apple,2025,416161,112010,359241,247364,133000
